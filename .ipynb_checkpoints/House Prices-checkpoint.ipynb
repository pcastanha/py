# %%
from __future__ import print_function

import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn.svm.classes import SVR

from sklearn.metrics import mean_absolute_error

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('C:\Pedro\Kaggle\House-Prices\\train.csv', )
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
#df = df.drop(['Alley', 'PoolQC', 'Fence', 'MiscFeature'], axis=1) # Removing because of too few registers
#df = df.fillna(df.mean())
df[df.MasVnrType.isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 234    235          60       RL          NaN     7851   Pave      Reg
# 529    530          20       RL          NaN    32668   Pave      IR1
# 650    651          60       FV         65.0     8125   Pave      Reg
# 936    937          20       RL         67.0    10083   Pave      Reg
# 973    974          20       FV         95.0    11639   Pave      Reg
# 977    978         120       FV         35.0     4274   Pave      IR1
# 1243  1244          20       RL        107.0    13891   Pave      Reg
# 1278  1279          60       RL         75.0     9473   Pave      Reg
#
#      LandContour Utilities LotConfig    ...     EnclosedPorch 3SsnPorch  \
# 234          Lvl    AllPub    Inside    ...                 0         0
# 529          Lvl    AllPub   CulDSac    ...               200         0
# 650          Lvl    AllPub    Inside    ...                 0         0
# 936          Lvl    AllPub    Inside    ...                 0         0
# 973          Lvl    AllPub    Corner    ...                 0         0
# 977          Lvl    AllPub    Inside    ...                 0         0
# 1243         Lvl    AllPub    Inside    ...                 0         0
# 1278         Lvl    AllPub    Inside    ...                 0         0
#
#      ScreenPorch PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  \
# 234            0        0       0      5    2010        WD         Normal
# 529            0        0       0      3    2007        WD         Alloca
# 650            0        0       0      5    2008        WD         Normal
# 936            0        0       0      8    2009        WD         Normal
# 973            0        0       0     12    2008       New        Partial
# 977            0        0       0     11    2007       New        Partial
# 1243           0        0       0      9    2006       New        Partial
# 1278           0        0       0      3    2008        WD         Normal
#
#       SalePrice
# 234      216500
# 529      200624
# 650      205950
# 936      184900
# 973      182000
# 977      199900
# 1243     465000
# 1278     237000
#
# [8 rows x 77 columns]
